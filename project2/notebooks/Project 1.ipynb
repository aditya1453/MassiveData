# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 1. Read Data

# %%
order = pd.read_csv('../data/raw/ecommerce.csv', encoding ='ISO-8859-1', parse_dates= ["InvoiceDate"])
order.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# 1. InvoiceNo: Invoice number. If this code starts with letter 'c', it indicates a cancellation.
# 2. StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# 3. Description: Product (item) name. Nominal.
# 4. Quantity: The quantities of each product (item) per transaction. Numeric.
# 5. InvoiceDate: Invoice Date and time. Numeric, the day and time when each transaction was generated.
# 6. UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# 7. CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# 8. Country: Country name. Nominal, the name of the country where each customer resides.

# %%
order.shape
# Out:
# (541909, 8)

# %%
order.set_index(['InvoiceDate'], inplace=True)
order.head()
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#                      Quantity  UnitPrice  CustomerID         Country
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         8       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom

# %%
order.index
# Out:
# DatetimeIndex(['2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:26:00',
#                '2010-12-01 08:26:00', '2010-12-01 08:28:00',
#                '2010-12-01 08:28:00', '2010-12-01 08:34:00',
#                ...
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00',
#                '2011-12-09 12:50:00', '2011-12-09 12:50:00'],
#               dtype='datetime64[ns]', name='InvoiceDate', length=541909, freq=None)

# %% [markdown]
# ### 2. Handle Missing Data

# %%
order.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Assign "unknown" and -99999 to handle missing data in description and CostumerID column.

# %%
order.fillna({})
order = order.fillna({
    'Description': 'unknown',
    'CustomerID' : -99999
})
order.head()
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#                      Quantity  UnitPrice  CustomerID         Country
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         8       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom

# %%
order.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ### 3. Check the Datatype

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 541909 entries, 2010-12-01 08:26:00 to 2011-12-09 12:50:00
# Data columns (total 7 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    541909 non-null object
# Quantity       541909 non-null int64
# UnitPrice      541909 non-null float64
# CustomerID     541909 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
print("InvoiceNo    :", type(order.InvoiceNo[0]))
print("StockCode    :", type(order.StockCode[0]))
print("Description  :", type(order.Description[0]))
print("Quantity     :", type(order.Quantity[0]))
print("UnitPrice    :", type(order.UnitPrice[0]))
print("CustomerID   :", type(order.CustomerID[0]))
print("Country      :", type(order.Country[0]))
# Out:
# InvoiceNo    : <class 'str'>
# StockCode    : <class 'str'>
# Description  : <class 'str'>
# Quantity     : <class 'numpy.int64'>
# UnitPrice    : <class 'numpy.float64'>
# CustomerID   : <class 'numpy.float64'>
# Country      : <class 'str'>

# %% [markdown]
# Note :
# 1. InvoiceNo's and StockCode's data type are a string because some of the data starts with a character 'c'. It means the costumer make a cancelation.
# 2. CostumerID's data type is a float, it should be an integer.

# %%
order.Quantity.astype("int")
print("Quantity     :", type(order.Quantity[0]))
# Out:
# Quantity     : <class 'numpy.int64'>

# %% [markdown]
# ### 4. Handle Wrong Format

# %% [markdown]
# Let's check wrong format in each column.

# %%
df = order[order['Quantity']<=0]
print(df.shape)
df.head()
# Out:
# (10624, 7)
#                     InvoiceNo StockCode                       Description  \
# InvoiceDate
# 2010-12-01 09:41:00   C536379         D                          Discount
# 2010-12-01 09:49:00   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS
# 2010-12-01 10:24:00   C536391     22556    PLASTERS IN TIN CIRCUS PARADE
# 2010-12-01 10:24:00   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES
# 2010-12-01 10:24:00   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES
#
#                      Quantity  UnitPrice  CustomerID         Country
# InvoiceDate
# 2010-12-01 09:41:00        -1      27.50     14527.0  United Kingdom
# 2010-12-01 09:49:00        -1       4.65     15311.0  United Kingdom
# 2010-12-01 10:24:00       -12       1.65     17548.0  United Kingdom
# 2010-12-01 10:24:00       -24       0.29     17548.0  United Kingdom
# 2010-12-01 10:24:00       -24       0.29     17548.0  United Kingdom

# %%
df.Description.unique()
# Out:
# array(['Discount', 'SET OF 3 COLOURED  FLYING DUCKS',
#        'PLASTERS IN TIN CIRCUS PARADE ', ...,
#        'SMALL SQUARE CUT GLASS CANDLESTICK',
#        'HOUSE SHAPE PENCIL SHARPENER', 'PAPER CRAFT , LITTLE BIRDIE'],
#       dtype=object)

# %%
df = order[order['StockCode']=='D']
print(df.shape)
df.head()
# Out:
# (77, 7)
#                     InvoiceNo StockCode Description  Quantity  UnitPrice  \
# InvoiceDate
# 2010-12-01 09:41:00   C536379         D    Discount        -1      27.50
# 2010-12-05 13:21:00   C537164         D    Discount        -1      29.29
# 2010-12-07 12:34:00   C537597         D    Discount        -1     281.00
# 2010-12-08 16:00:00   C537857         D    Discount        -1     267.12
# 2010-12-15 09:14:00   C538897         D    Discount        -1       5.76
#
#                      CustomerID         Country
# InvoiceDate
# 2010-12-01 09:41:00     14527.0  United Kingdom
# 2010-12-05 13:21:00     14527.0  United Kingdom
# 2010-12-07 12:34:00     15498.0  United Kingdom
# 2010-12-08 16:00:00     17340.0  United Kingdom
# 2010-12-15 09:14:00     16422.0  United Kingdom

# %%
df = order[order['UnitPrice']<0]
print(df.shape)
df
# Out:
# (2, 7)
#                     InvoiceNo StockCode      Description  Quantity  UnitPrice  \
# InvoiceDate
# 2011-08-12 14:51:00   A563186         B  Adjust bad debt         1  -11062.06
# 2011-08-12 14:52:00   A563187         B  Adjust bad debt         1  -11062.06
#
#                      CustomerID         Country
# InvoiceDate
# 2011-08-12 14:51:00    -99999.0  United Kingdom
# 2011-08-12 14:52:00    -99999.0  United Kingdom

# %% [markdown]
# It is possible to get the price equals to zero. So we keep the data.

# %% [markdown]
# We don't need Discount and "Adjust Bad Debt" data, so we'll delete this data on the order data frame.

# %%
df = order[order['UnitPrice']==0]
df = df[df['Quantity']>0]
print(df.shape)
df
# Out:
# (1179, 7)
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01
# 2011-12-02 16:38:00         6        0.0    -99999.0  United Kingdom
# 2011-12-02 16:38:00         1        0.0    -99999.0  United Kingdom
# 2011-12-02 17:49:00         8        0.0    -99999.0  United Kingdom
# 2011-12-04 10:37:00         1        0.0    -99999.0  United Kingdom
# 2011-12-04 10:42:00         1        0.0    -99999.0  United Kingdom
# 2011-12-05 09:54:00        66        0.0    -99999.0  United Kingdom
# 2011-12-05 10:33:00        10        0.0    -99999.0  United Kingdom
# 2011-12-05 10:34:00         4        0.0    -99999.0  United Kingdom
# 2011-12-05 10:35:00         5        0.0    -99999.0  United Kingdom
# 2011-12-05 11:41:00         1        0.0    -99999.0  United Kingdom
# 2011-12-06 09:30:00         1        0.0    -99999.0  United Kingdom
# 2011-12-07 11:57:00        20        0.0    -99999.0  United Kingdom
# 2011-12-07 11:58:00         4        0.0    -99999.0  United Kingdom
# 2011-12-07 18:30:00        41        0.0    -99999.0  United Kingdom
# 2011-12-07 18:31:00        15        0.0    -99999.0  United Kingdom
# 2011-12-07 18:35:00         6        0.0    -99999.0  United Kingdom
# 2011-12-07 18:36:00        14        0.0    -99999.0  United Kingdom
# 2011-12-08 10:33:00        27        0.0    -99999.0  United Kingdom
# 2011-12-08 13:58:00       240        0.0    -99999.0  United Kingdom
# 2011-12-08 13:58:00       300        0.0    -99999.0  United Kingdom
# 2011-12-08 14:06:00        20        0.0    -99999.0  United Kingdom
#
# [1179 rows x 7 columns]

# %%
real_order = order[order['Quantity']  > 0]
real_order = real_order[real_order['UnitPrice'] > 0]
real_order.shape
# Out:
# (0, 7)

# %% [markdown]
# ### 4. Check Duplicate Data

# %%
duplicate_order = order[order.duplicated()]
duplicate_order
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6918b9b79bec> in <module>
# ----> 1 duplicate_order = order[order.duplicated()]
#       2 duplicate_order
#
# NameError: name 'order' is not defined

# %% [markdown]
# There is no duplicate data in the dataframe.

# %% [markdown]
# ### 5. Separate Dataframe Between Real & Cancel Order

# %% [markdown]
# #### 5.1 Real Order

# %% [markdown]
# Real order can be identify from invoice number or quantity.
# The cancelation order happen if invoice number started with 'c' or the quantity less than zero.

# %%
real_order   = order[order['Quantity']>0 ]
real_order   = order[order['UnitPrice']>0 ]
real_order.head()

# %%
real_order.shape

# %%
num_real = real_order.shape[0]
print('Real Order persentage %f%%' %(num_real/order.shape[0]*100))

# %% [markdown]
# #### 5.2 Cancel Order

# %%
cancel_order = order[order['Quantity']<0]
cancel_order.head()

# %%
cancel_order.shape

# %%
num_cancel = cancel_order.shape[0]
print('cancelation persentage %f%%' %(num_cancel/order.shape[0]*100))

# %% [markdown]
# #### 5.3 Bad Debt

# %%
bad_debt = order[order['UnitPrice']<0]
bad_debt

# %%
num_bad = bad_debt.shape[0]
print('Bad Debt persentage %f%%' %(num_bad/order.shape[0]*100))

# %% [markdown]
# ### 6. Data Visualization
